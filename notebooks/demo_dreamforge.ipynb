# %% [markdown]
# # DREAMFORGE demoRun world_generator.py from the notebook or CLI.

# %%
# !python world_generator.py --prompt "a frozen desert ruled by glass cities" --out demo_world.md
# !sed -n '1,200p' demo_world.md
